# %% [markdown]
# # LABORATORIO 02 - INSERTION SORT
# ## -Jerónimo Urrego Morales
# ## -Andrés Felipe Rubio Arango
# ## -Daniel Felipe Cárdenas Romero
#
# En este laboratorio trabajaremos con el algoritmo de ordenamiento de Insertion Sort,
# haremos un programa que organice los precios de n productos de un supermercado de manera
# ascendente o descendente, esto depende de como lo desee el usuario.
#
# ## CONTENIDO
# - Enunciado
# - Especificacion
# - Diseño
# - Codigo
# - Seccion de Complejidad
# - Retrospectiva
#
# ### ENUNCIADO
# Ejercicio: Organización de precios en una tienda
# Una tienda necesita organizar los precios de sus productos. La cantidad de productos puede variar,
# por lo que el usuario deberá indicar cuántos precios desea registrar.
#
# El programa debe solicitar:
#
# - La cantidad de productos, representada por n.
# - El precio de cada uno de los productos.
# - El tipo de ordenamiento que se desea mostrar.
# - Después de ingresar los datos, el programa deberá utilizar el algoritmo Insertion Sort para organizar los precios.
#
# Punto 1. Orden ascendente
# Ordenar los precios desde el menor hasta el mayor, con el fin de mostrar primero los productos más económicos.
#
# Punto 2. Orden descendente
# Ordenar los precios desde el mayor hasta el menor, con el fin de mostrar primero los productos más costosos.
#
#
# Se debe entregar en la carpeta de git de la semana 2 haciendo uso de un PR con dos revisores
#
# ### ESPECIFICACION:
#
# #### Que recibe el programa?
# - Un numero entero n que representa la cantidad total de productos a registrar
# - Un arreglo de n numeros que representa los precios de cada producto denotada como P = [P1, P2, ..., Pn]
# - Un indicador o variable de estado O que define el tipo de ordenamiento deseado por el usuario (ascendente o descendente)
#
# #### Que debe producir el programa?
# - Un arreglo P' que es una permutacion del arreglo original de precios P, ya sido ordenada internamente
#     mediante el algoritmo Insertion Sort
# - Si O es ascendente el arreglo resultante cummple con la propiedad P'1 <= P'2' <= P'n.
#     Si O es Descendente el arreglo resultante cumple con la propiedad P'1 >= P'2 >= P'n.
#
# #### Que restricciones tiene el programa?
# - Dominio de n: La cantidad de productos debe ser un número entero estrictamente positivo (n>=1).
# - Dominio de los precios: Cada precio Pi dentro del arreglo debe ser un número real mayor o igual a cero (Pi >= 0).
# - Validación de opción: La selección del tipo de ordenamiento debe limitarse únicamente a las dos opciones dadas (ascendente o descendente); el programa debe manejar ingresos no válidos.
# - Restricción algorítmica: Es obligatorio implementar la lógica pura del algoritmo de Insertion Sort. No se permite el uso de métodos de ordenamiento nativos incorporados en el lenguaje de programación (como sort(), Arrays.sort(), etc.).
#
# #### Diagrama de flujos:
# ![image.png](attachment:image.png)
#
# #### Requerimentos Funcionales y no Funcionales:
# ##### Requerimentos Funcionales
#     1. Lectura de n: El sistema debe solicitar y validar un entero positvo n
#     2. Lectura de precios: El sistema debe capturar n precios float o reales mayores a 0
#     3. Seleccion de criterio: El sistema permitir elegir entre orden ascendente o descendente
#     4. Algoritmo: El sistema debe realizar el ordenamiento utilizando Insertion Sort
#     5. Resultados: El sistema debe mostrar el arreglo ordenado resultante
#
# ##### Requerimentos no Funcionales
#     1. Usabilidad: El proggrama no se debe crashear si el usuario ingresa un valor no valido.
#     2. Mantenibilidad: Codigo estructurado, modularizado en funciones.
#
# ### DISEÑO
# #### Estrategia de Solucion
# Primero se creara una funcion que permita al usuario ingresa un numero entero n correspondiente a la cantidad de
# productos para preguntar despues su precio, tras eso se creara un arreglo de tamaño n en el cual se le preguntara al usuario el precio de cada producto.
#
# Posteriormente se preguntara al usuario si quiere ordenar el arreglo de manera ascendente o descendente, se enviara el arreglo como parametro a una funcion que lo ordene dependiendo de la decision de la decision del usuario.
#
# Se retornara el arreglo ordenado y se imprimira en pantalla.
#
# #### Tipo de Algoritmo
# Se utilizara Insertion Sort, un algoritmo de ordenamiento que compara los elementos de un arreglo uno por uno, hasta que quede ordenado, su funcionamiento puede verse como el ordenamiento de una baraja de cartas, asume que el primer elemento está ordenado y, uno por uno, toma los siguientes elementos para compararlos de derecha a izquierda con los que ya están en la parte ordenada, desplazando los valores necesarios para abrir un hueco e "insertar" el elemento actual en su posición correcta.
#
# #### Tipo de implementacion
# - Iterativa, la solucion implementara ciclos anidados (un for y un while) para recorrer y comparar los precios.
# - Incremental, el algoritmo procesa un precio a la vez, haciéndole un espacio y agregándolo a un subarreglo que va creciendo de forma ordenada hasta completar todos los datos.
# - Invariante de ciclo: Al inicio de cada iteración $i$, el subarreglo que va desde la posición $0$ hasta $i-1$ contiene los elementos que fueron evaluados hasta el momento, pero ya se encuentran perfectamente ordenados (ya sea de forma ascendente o descendente).
#
# --- JUSTIFICACION ---
# - Requisito: El problema exige explícitamente el uso de Insertion Sort, por lo que esta implementación cumple al 100% con los requerimientos técnicos.
# - Eficiencia en el mundo real: Si el administrador de la tienda ingresa los precios en un orden que ya está parcialmente ordenado, el algoritmo se vuelve extremadamente rápido (acercándose a su mejor caso computacional O(n)).
#
# #### CODIGO

# %%
def ingresar_datos():
    """
    Función que pide al usuario la cantidad de productos y sus precios.
    """
    n = 0 
    while n < 1:
        n = int(input("Ingrese la cantidad de productos a registrar: "))
        if n < 1:
            print("Error: La cantidad de productos debe ser mayor o igual a 1.")

    precios = []
    
    print("\n--- Ingreso de precios ---")
    for rep in range(n):
        precio = -1.0
        while precio < 0:
            precio = float(input(f"Ingrese el precio del producto {rep + 1}: $"))
            if precio < 0:
                print("Error: El precio no puede ser un valor negativo.")
        precios.append(precio)               
    return precios

def insertion_sort(arreglo, orden):
    """
    Función que recibe el arreglo y la opción de ordenamiento,
    y retorna el arreglo ordenado usando el algoritmo Insertion Sort.
    """
    n = len(arreglo)
    for rep in range(1, n):
        llave = arreglo[rep]
        rep_ant = rep - 1
        # Orden Ascendente
        if orden == 1:
            while rep_ant >= 0 and arreglo[rep_ant] > llave:
                arreglo[rep_ant + 1] = arreglo[rep_ant]
                rep_ant = rep_ant - 1
        # Orden Descendente
        elif orden == 2:
            while rep_ant >= 0 and arreglo[rep_ant] < llave:
                arreglo[rep_ant + 1] = arreglo[rep_ant]
                rep_ant = rep_ant - 1
        arreglo[rep_ant + 1] = llave
    return arreglo

def main():
    arreglo_precios = ingresar_datos()
    print("\n--- Menú de Ordenamiento ---")
    print("1. Orden ascendente (del más económico al más costoso)")
    print("2. Orden descendente (del más costoso al más económico)")
    opcion = 0
    while opcion != 1 and opcion != 2:
        opcion = int(input("Ingrese el número de la opción deseada (1 o 2): "))
        if opcion != 1 and opcion != 2:
            print("Error: Selección no válida. Ingrese 1 o 2.")

    precios_ordenados = insertion_sort(arreglo_precios, opcion)
    print("\n--- Lista de precios organizada ---")
    for rep in range(len(precios_ordenados)):
        print(f"$ {precios_ordenados[rep]}")
main()

# %% [markdown]
# ### Costos
#
# #### Tabla de Costos
#
# ![image.png](attachment:image.png)
#
#
# #### T(n)
#
# ![image-2.png](attachment:image-2.png)
#
# #### Best case:
# El mejor caso ocurre cuando el arreglo ya está ordenado en la forma deseada (en este caso, de menor a mayor).
# Al llegar al ciclo while, la condición arreglo[j] > llave es inmediatamente falsa en el primer intento.
# Valor de ti: El ciclo se evalúa solo 1 vez por cada iteración del for. Por lo tanto, ti = 1
#
# ##### Ecuacion:
# ![image-3.png](attachment:image-3.png)
#
# Al simplificar obtenemos una funcion lineal de la forma T(n):an+b, su complejidad BigOh O(n)
#
# ##### Grafica:
# ![image-4.png](attachment:image-4.png)
#
#
# #### Worst Case:
# El peor caso ocurre cuando el arreglo está ordenado de forma inversamente proporcional a la deseada (ej. está descendente y queremos ordenarlo ascendente).
#
# ##### Ecuacion:
# ![image-3.png](attachment:image-3.png)
#
# Al simplificar obtenemos una funcion cuadrática de la forma T(n):ax²+bx+c, su complejidad BigOh O(n²)
#
# ##### Grafica:
# ![,,,.png](attachment:,,,.png)
#
#
# #### RETROSPECTIVA IA
#
# ##### En que le ayudo la IA?
# Como grupo hemos utilizado la IA para entender algunos conceptos importantes que debiamos trabajar en el Lab, por ejemplo la hemos utilizado como ayuda en el tema de calcular costos de un programa, entender de mejor manera el funcionamiento del algoritmo (Insertion Sort) y en algunos casos para poder expresar mejor lo que queremos plasmar en este laboratorio.
#
# ##### ¿Qué parte del problema no entendía al inicio?
# Realmente el problema no nos genero ninguna complicacion, logramos entenderlo y el como solucionarlo.
#
# ##### ¿Qué aprendió realmente?
# Como grupo consideramos que tuvimos un primer buen acercamiento a este tipo de algoritmos de ordenamiento, aprendimos tambien el como "documentabamos" correctamente un programa, ya que por lo general nunca nos adentrabamos tan profundamente en este tema, sin embargo, creo que la mayor complejidad encontrada, fue precisamente encontrar la complejidad de los algoritmos, creemos que fue lo que mas nos sentimos perdidos.
